# %% [markdown]
# <a href="https://colab.research.google.com/github/IshbuldinRobert/123-Robert-/blob/main/lection_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
df['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.head(n = 10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0
# 7       375.0       158.0         1.7083             48500.0
# 8      3134.0      1056.0         2.1782             58400.0
# 9       787.0       271.0         2.1908             48100.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.tail(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df[['population', 'median_income']]
# Out:
#        population  median_income
# 0          1015.0         1.4936
# 1          1129.0         1.8200
# 2           333.0         1.6509
# 3           515.0         3.1917
# 4           624.0         1.9250
# ...           ...            ...
# 16995       907.0         2.3571
# 16996      1194.0         2.5179
# 16997      1244.0         3.0313
# 16998      1298.0         1.9797
# 16999       806.0         3.0147
#
# [17000 rows x 2 columns]

# %%
df[(df['housing_median_age'] < 20) & (df['housing_median_age'] > 15)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 15       -114.65     34.89                17.0       2556.0           587.0
# 18       -114.66     32.74                17.0       1388.0           386.0
# ...          ...       ...                 ...          ...             ...
# 16946    -124.14     40.59                17.0       2985.0           610.0
# 16949    -124.15     41.81                17.0       3276.0           628.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
#        population  households  median_income  median_house_value
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 10         2434.0       824.0         2.6797             86500.0
# 15         1005.0       401.0         1.6991             69100.0
# 18          775.0       320.0         1.2049             44000.0
# ...           ...         ...            ...                 ...
# 16946      1544.0       584.0         2.1780             76800.0
# 16949      3546.0       585.0         2.2868            103100.0
# 16987      1947.0       647.0         2.5795             68400.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
#
# [2101 rows x 9 columns]

# %%
df[df['population'] > 1300][['housing_median_age', 'population']]
# Out:
#        housing_median_age  population
# 6                    25.0      1841.0
# 8                    34.0      3134.0
# 10                   16.0      2434.0
# 13                   31.0      1346.0
# 24                   18.0      3424.0
# ...                   ...         ...
# 16986                21.0      2907.0
# 16987                17.0      1947.0
# 16988                20.0      1993.0
# 16990                28.0      1530.0
# 16991                11.0      1343.0
#
# [7222 rows x 2 columns]

# %% [markdown]
# ## Простая статистика

# %%
print(df['population'].max())
# Out:
# 35682.0

# %%
print(df['population'].min())
# Out:
# 3.0

# %%
print(df['population'].mean())
# Out:
# 1429.5739411764705

# %%
print(df['population'].sum())
# Out:
# 24302757.0

# %%
df[['population', 'total_rooms']].median()
# Out:
# population     1167.0
# total_rooms    2127.0
# dtype: float64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='population', y='households')
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %%
sns.scatterplot(data=df, x='population', y='households', hue='total_rooms')
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %%
sns.scatterplot(data=df, x='population', y='households', hue='total_rooms', size=10)
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %%
cols = ['population', 'total_rooms', 'households', 'total_bedrooms']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %% [markdown]
# # Линейные графики

# %%
sns.relplot(x='latitude', y='median_house_value', data=df, kind='line')

# %%
sns.relplot(data=df, x='longitude', y='median_house_value', kind='line')

# %%
sns.scatterplot(data=df, x='latitude', y='longitude', hue='median_house_value')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# # Гистограмма

# %%
sns.histplot(data=df, x='median_income')
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
sns.histplot(data=df, x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data=df[df['housing_median_age'] > 50], x='median_income')
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
df.loc[df['housing_median_age'] <= 20, 'housing_median_age']
# Out:
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
#          ...
# 16987    17.0
# 16988    20.0
# 16991    11.0
# 16997    17.0
# 16998    19.0
# Name: housing_median_age, Length: 5209, dtype: float64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.loc[df['housing_median_age'] <= 20, 'age_group'] = 'Молодые'
df.loc[(df['housing_median_age'] > 20) & (df['housing_median_age'] <= 50), 'age_group'] = 'Ср. возраст'
df.loc[df['housing_median_age'] > 50, 'age_group'] = 'Пожилые'

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'age_group'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value    age_group
# 0      1015.0       472.0         1.4936             66900.0      Молодые
# 1      1129.0       463.0         1.8200             80100.0      Молодые
# 2       333.0       117.0         1.6509             85700.0      Молодые
# 3       515.0       226.0         3.1917             73400.0      Молодые
# 4       624.0       262.0         1.9250             65500.0      Молодые
# 5       671.0       239.0         3.3438             74000.0  Ср. возраст
# 6      1841.0       633.0         2.6768             82400.0  Ср. возраст
# 7       375.0       158.0         1.7083             48500.0  Ср. возраст
# 8      3134.0      1056.0         2.1782             58400.0  Ср. возраст
# 9       787.0       271.0         2.1908             48100.0  Ср. возраст

# %%
df.groupby('age_group')['median_income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='age_group'>

# %%
df.loc[df['median_income'] > 6, 'income_group'] = 'rich'
df.loc[df['median_income'] < 6, 'income_group'] = 'everyone_else'

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'age_group', 'income_group'],
#       dtype='object')

# %%
sns.histplot(data=df, x='median_house_value', hue='income_group')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>
